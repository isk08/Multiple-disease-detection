# %% [markdown]
# # Brain Tumor Detection with CNN | Beginner Friendly
#
# **1. Importing the Libraries**
#
# **2. Downloading the Images**
#
# **3. Data Visualization**
#
# **4. Split the Data**
#
# **5. Preprocessing**
#
# **6. Data Augmentation**
#
# **7. CNN Model**
#
# **8. Results**

# %%
# !pip install tensorflow

# %% [markdown]
# # 1. Importing the Libraries

# %%
# import numpy as np
# import pandas as pd
# import os
# from PIL import Image
# from sklearn.model_selection import train_test_split
# import seaborn as sns
# import matplotlib.pyplot as plt
# import cv2
# import tensorflow as tf
# import tensorflow 
# from tensorflow import keras
# from keras.models import Sequential
# from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
# from keras.utils import to_categorical
# from sklearn.metrics import confusion_matrix
# import tensorflow as tf
# from tensorflow.keras.preprocessing.image import ImageDataGenerator


import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # 2. Downloading the Images

# %%
data = []
labels = []

for tumor_type in ['yes', 'no']:
    for r, d, f in os.walk(f"Dataset/brain_tumor_dataset/{tumor_type}"):
        for file in f:
            if '.jpg' in file:
                
                # image path
                path = os.path.join(r, file)
                
                # read the image and resize
                img = Image.open(path)
                img = img.resize((128,128))
                img = np.array(img)
                
                # if the size of the image is true
                if img.shape == (128,128,3):
                    data.append(img)
                    
                    label = 0 if tumor_type == 'yes' else 1
                    labels.append(label)

# %%
data = np.array(data)
print(data.shape)
# Out:
# (139, 128, 128, 3)

# %%
labels = np.array(labels)
print(labels.shape)
# Out:
# (139,)

# %% [markdown]
# # 3. Data Visualization

# %%
num_samples_to_display = 5
random_indices = np.random.choice(len(data), num_samples_to_display, replace=False)

plt.figure(figsize=(10, 5))
for i, idx in enumerate(random_indices):
    plt.subplot(1, num_samples_to_display, i + 1)
    plt.imshow(data[idx], interpolation='nearest')
    plt.title('Tumor' if labels[idx] == 0 else 'No Tumor')
    plt.axis('off')
plt.show()

# %% [markdown]
# # 4. Split the Data

# %%
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size= 0.3, random_state= 42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (97, 128, 128, 3)
# (42, 128, 128, 3)

# %% [markdown]
# ## Data Distribution

# %%
#Train
plt.figure(figsize=(4, 3))
plt.hist(y_train, bins=np.arange(3)-0.5, alpha=0.5, color='blue', edgecolor='black', linewidth=1.2)
plt.xticks([0, 1])  
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Train Data Class Distribution')
plt.grid(True)
plt.show()

#Test
plt.figure(figsize=(4, 3))
plt.hist(y_test, bins=np.arange(3)-0.5, alpha=0.5, color='red', edgecolor='black', linewidth=1.2)
plt.xticks([0, 1])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Test Data Class Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# # 5. Preprocessing

# %%
def preProcess(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.equalizeHist(img)
    img = img/255
    
    return img

# %%
x_train = np.array(list(map(preProcess, x_train)))
x_test = np.array(list(map(preProcess, x_test)))

# %%
x_train = x_train.reshape(-1, 128, 128,1)
x_test = x_test.reshape(-1, 128, 128,1)

# %% [markdown]
# # 6. Data Augmentation

# %%
dataGen = ImageDataGenerator(width_shift_range= 0.1,
                             height_shift_range= 0.1,
                             zoom_range= 0.1,
                             rotation_range= 10)

# %%
dataGen.fit(x_train)

# %%
y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)

# %% [markdown]
# # 7. CNN Model

# %%
model = Sequential()
model.add(Conv2D(32,input_shape = (128,128,1), kernel_size = (5,5), activation="relu", padding = "same"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, kernel_size = (3,3), activation="relu", padding = "same"))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(units=256, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(units= 2, activation="softmax"))

model.compile(loss = "categorical_crossentropy", optimizer = ("Adam"), metrics=["accuracy"])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1, validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 878ms/step - accuracy: 0.3823 - loss: 0.7168 - val_accuracy: 0.5714 - val_loss: 0.6800
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 515ms/step - accuracy: 0.4404 - loss: 0.6928 - val_accuracy: 0.7381 - val_loss: 0.6803
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 497ms/step - accuracy: 0.5338 - loss: 0.6888 - val_accuracy: 0.7619 - val_loss: 0.6697
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 523ms/step - accuracy: 0.6333 - loss: 0.6700 - val_accuracy: 0.5714 - val_loss: 0.6504
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 613ms/step - accuracy: 0.6177 - loss: 0.6497 - val_accuracy: 0.7619 - val_loss: 0.5514
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 521ms/step - accuracy: 0.6426 - loss: 0.5939 - val_accuracy: 0.7619 - val_loss: 0.4739
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 506ms/step - accuracy: 0.5793 - loss: 0.6627 - val_accuracy: 0.7857 - val_loss: 0.5155
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 544ms/step - accuracy: 0.6632 - loss: 0.5644 - val_accuracy: 0.5714 - val_loss: 0.6396
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 509ms/step - accuracy: 0.6715 - loss: 0.6030 - val_accuracy: 0.6905 - val_loss: 0.5791
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 529ms/step - accuracy: 0.7193 - loss: 0.5645 - val_accuracy: 0.7381 - val_loss: 0.4888
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 548ms/step - accuracy: 0.6508 - loss: 0.5349 - val_accuracy: 0.6905 - val_loss: 0.5346
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 528ms/step - accuracy: 0.7794 - loss: 0.5101 - val_accuracy: 0.7619 - val_loss: 0.3666
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - accuracy: 0.7057 - loss: 0.5329 - val_accuracy: 0.6905 - val_loss: 0.5735
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 512ms/step - accuracy: 0.7555 - loss: 0.5108 - val_accuracy: 0.6905 - val_loss: 0.4891
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 502ms/step - accuracy: 0.7928 - loss: 0.4588 - val_accuracy: 0.7857 - val_loss: 0.4299
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 734ms/step - accuracy: 0.7555 - loss: 0.4441 - val_accuracy: 0.6667 - val_loss: 0.5188
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 674ms/step - accuracy: 0.7967 - loss: 0.4519 - val_accuracy: 0.6905 - val_loss: 0.4325
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 813ms/step - accuracy: 0.8269 - loss: 0.3672 - val_accuracy: 0.7381 - val_loss: 0.3731
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.8394 - loss: 0.3478 - val_accuracy: 0.6667 - val_loss: 0.6055
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 915ms/step - accuracy: 0.8041 - loss: 0.3922 - val_accuracy: 0.7143 - val_loss: 0.4159
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 667ms/step - accuracy: 0.8817 - loss: 0.2956 - val_accuracy: 0.6905 - val_loss: 0.5633
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 681ms/step - accuracy: 0.8683 - loss: 0.3052 - val_accuracy: 0.7143 - val_loss: 0.4125
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 713ms/step - accuracy: 0.9586 - loss: 0.2003 - val_accuracy: 0.7381 - val_loss: 0.3864
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 799ms/step - accuracy: 0.9264 - loss: 0.1966 - val_accuracy: 0.7143 - val_loss: 0.6860
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 668ms/step - accuracy: 0.9089 - loss: 0.1966 - val_accuracy: 0.7143 - val_loss: 0.5489
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 738ms/step - accuracy: 0.9213 - loss: 0.1761 - val_accuracy: 0.6667 - val_loss: 0.5946
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 647ms/step - accuracy: 0.9503 - loss: 0.1322 - val_accuracy: 0.6429 - val_loss: 0.7933
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 696ms/step - accuracy: 0.9917 - loss: 0.0840 - val_accuracy: 0.6905 - val_loss: 0.8250
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 695ms/step - accuracy: 0.9794 - loss: 0.0823 - val_accuracy: 0.7857 - val_loss: 0.6977
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 547ms/step - accuracy: 0.9866 - loss: 0.0803 - val_accuracy: 0.7143 - val_loss: 0.8118

# %% [markdown]
# # 8. Results

# %%
plt.figure()
plt.plot(history.history["loss"], label = "Train Loss")
plt.plot(history.history["val_loss"], label = "Val Loss")
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history["accuracy"], label = "Train accuracy")
plt.plot(history.history["val_accuracy"], label = "Val accuracy")
plt.legend()
plt.show()

# %%
score = model.evaluate(x_test,y_test, verbose = 1)
print("Test loss: ", score[0])
print("Test accuracy: ", score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7366 - loss: 1.2047
# Test loss:  1.4279706478118896
# Test accuracy:  0.7142857313156128

# %%
y_pred = model.predict(x_test)

y_pred_class = np.argmax(y_pred, axis = 1)

Y_true = np.argmax(y_test, axis= 1)

cm = confusion_matrix(Y_true, y_pred_class)

f, ax = plt.subplots(figsize = (4,4))
sns.heatmap(cm, annot= True, linewidths= 0.01, cmap = "Greens", linecolor="gray", fmt= ".1f", ax = ax)
plt.xlabel("predicted")
plt.ylabel("true")
plt.title("cm")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
